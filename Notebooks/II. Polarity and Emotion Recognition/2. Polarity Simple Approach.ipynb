# %% [markdown]
# #### Simple Approach - Semtiment Analysis
# In this notebook, we apply a simple approach to analyse the sentiments of the tweets. we use a textblob library which has a support for 3 languages, English, French, and German.. the top three frequent languages in Switzerland.
#
# We do a simpe cleaning befor using TextBlob Sentiment Analyzer, such as removing https links, hashtags and mentions.

# %%
import pandas as pd
from textblob import TextBlob
import numpy as np
import  csv
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 
import re

# %%
tweet=pd.read_csv('tweets_with_canton_language_short.csv')

# %%
len(tweet)
# Out:
# 12579034

# %%
## text cleaning

def clean_up_text(text):
    '''
    remove https links, hashtags and mentions
    '''
    hashtag = re.compile(r'[#]\w*')
    https = re.compile(r'https?:\/\/[a-zA-z0-9\/#%\.]+')
    mention = re.compile(r'[@]\w*')
    text = re.sub(hashtag, '', text)
    text = re.sub(https, '', text)
    text = re.sub(mention, '', text)
    return text

# %% [markdown]
# # English

# %%
tweet_en=tweet[tweet['language']=='en']

# %%
len(tweet_en)
# Out:
# 2985994

# %%
text_list=tweet_en.text.tolist()

# %%
claned_text=[]
for t in text_list:
    claned_text.append(clean_up_text(t))

# %%
def get_sentiment_polarity(text):
    blob = TextBlob(text)
    return blob.polarity, blob.subjectivity

# %%
def study_sentiment(polarity_list, mid_point=0):
    '''
    The polarity score is a float within the range [-1.0, 1.0].
    The subjectivity is a float within the range [0.0, 1.0] 
    where 0.0 is very objective and 1.0 is very subjective.
    '''
    polarity_array = np.array(polarity_list)
    mean = np.mean(polarity_array)
    std = np.std(polarity_array)
    frac_positive = sum(polarity_array>mid_point)*1./len(polarity_array)
    frac_negative = sum(polarity_array<mid_point)*1./len(polarity_array)
    return mean, std, frac_positive,frac_negative

# %%
sentiment_analysis = map(get_sentiment_polarity, claned_text)
polarity_list = map(lambda x:x[0], sentiment_analysis)
sentiment_list = map(lambda x:x[1], sentiment_analysis)

# %%
po=[]
i=0
for a in polarity_list:
    #print(a)
    po.append(a)
    i+=1
    if (i%100000 == 0):
        print(i)
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000

# %%
len(po)
# Out:
# 2985994

# %%
len(tweet_en)
# Out:
# 2985994

# %%
tweet_en['polarity']=po
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tweet_en
# Out:
#                     id        userId            createdAt  \
# 0         9.514846e+09  7.198282e+06  2010-02-23 06:22:40
# 1         9.516574e+09  1.465788e+07  2010-02-23 07:34:25
# 2         9.516953e+09  1.470386e+07  2010-02-23 07:51:47
# 4         9.517917e+09  1.353540e+07  2010-02-23 08:35:39
# 6         9.519149e+09  1.426062e+07  2010-02-23 09:32:09
# 7         9.519738e+09  1.465788e+07  2010-02-23 09:59:41
# 8         9.521202e+09  6.589882e+06  2010-02-23 11:04:27
# 9         9.521790e+09  9.962022e+06  2010-02-23 11:28:27
# 10        9.521909e+09  1.439372e+07  2010-02-23 11:33:05
# 11        9.523489e+09  1.239192e+07  2010-02-23 12:30:04
# 12579031  7.768216e+17  1.933297e+07  2016-09-16 16:34:47
#
#                                                        text canton language  \
# 0         Still the best coffee in town — at La Stanza h...     ZH       en
# 1         It has been a week or so.. and today I just co...     GE       en
# 2                Getting ready..  http://twitpic.com/14v8gz     SG       en
# 4         I'm at Online PC Magazin in Adliswil http://go...     ZH       en
# 6         @eyeem When and how can we send photos ? One p...     AG       en
# 7         Magic spells run off after midnight, I guess s...     GE       en
# 8         I just became the mayor of Au couscous on @fou...     VD       en
# 9         Limitas of public transportation! No taxi, rai...     VD       en
# 10                   I'm at l'avenir. http://4sq.com/c9eQ4a     VD       en
# 11        I just ousted @keepthebyte as the mayor of Day...     BS       en
# 14        Greetings ! http://tinyurl.com/ycrdlhq #iPhone...     AG       en
# 15        Lexmark launches Evernote SmartSolution! Send ...     ZH       en
# 16        Google Reader's recommended items get personal...     ZH       en
# 17        Interesting, sounds natural &gt;&gt; A brief i...     ZH       en
# 18        Read & Learn about scalability!!! A brief inte...     ZH       en
# 19        That was a beautif gold medal. Congratulations...     VD       en
# 20        Good night Twitter-buds!! .. tomorrow morning ...     GE       en
# 22        Good morning! Black Eyed Peas in my ears, fina...     BE       en
# 23        I just became the mayor of Phonak AG on @fours...     ZH       en
# 28           Buying socks!! (@ Manor) http://4sq.com/c2HQ9s     VD       en
# 29        I'm at Coop Restaurant in Baden http://gowal.l...     AG       en
# 30                     I'm at Pöstli. http://4sq.com/d86MZo     AG       en
# 31        @akosma definitely, dropbox us great easy and ...     VD       en
# 32        I'm at Starbucks (place Saint-François 2, Laus...     VD       en
# 33        Beaut day, so had lunch on the balcony at work...     LU       en
# 34        I'm at Bettmeralp Schönbiel http://gowal.la/s/...     VS       en
# 35                    I'm at Aletsch http://gowal.la/s/46Xw     VS       en
# 37        Mobile testing success at local.ch - Bamboo ho...     ZH       en
# 38        I'm at Pat Pizza & Kebab (Avenue Tissot 17, La...     VD       en
# 39        massive miles&more in april: snowboarding swis...     SG       en
# ...                                                     ...    ...      ...
# 12578885  Kingler – bei McDonald's / roadhouse bis 18:31...     LU       en
# 12578895  I'm at Restaurant Vulkan in Zürich w/ @laurael...     ZH       en
# 12578906                   @Minimis21 it is :/ this Monday      TI       en
# 12578919  Great example of #onlinedonation website. @Mer...     VD       en
# 12578922          hold on... there's a song called no jam ?     VD       en
# 12578924  Ready for the storm. #rain #Geneva #autumn #sw...     GE       en
# 12578931  The shooting is done. The teaser is getting cl...     GE       en
# 12578932  IT'S A SONG CALLED NO JAM AND OF COURSE THE RA...     VD       en
# 12578934  LASTMINUTE REISEANGEBOTE 17.9-1.10. Lastminute...     ZH       en
# 12578935  Rory Cowan, Leadership in the digital era: "Pr...     VD       en
# 12578936  WHO LET THEM HAVE A SONG CALL NO JAM ON THE AL...     VD       en
# 12578943  @MarkGSparrow You have a listener tuned in fro...     ZG       en
# 12578957  This #job might be a great fit for you: System...     AG       en
# 12578960                          @mokposvocalist thank you     VD       en
# 12578963  Yay, day getting better. Flying home on the @B...     GE       en
# 12578964  no offense but prove it better be a song about...     VD       en
# 12578969  I'm at Interlaken in Interlaken, BE https://t....     BE       en
# 12578975  @acblet 1300 est. New York time. But... stay t...     GE       en
# 12578976      im starting to feel the pill all over my body     BS       en
# 12578983  Interesting concept: @emirates plans your next...     BE       en
# 12578985   WHAT HAPPENED TO MY FACE https://t.co/xfiiZmNhBc     GE       en
# 12578988      Sone quality shitpost https://t.co/6u0vaOu19u     ZH       en
# 12578993  #WomenMood (29/40) - #today I take #pictures f...     GE       en
# 12578994  What a week #TOP100SwissSU #PowerDinner #DiFi1...     ZH       en
# 12579000  It was so nice to see my cousin Yoan again aft...     ZH       en
# 12579003  Temp: 14.9°C Vent:4.8kmh Pression: 1016.03hpa ...     VS       en
# 12579008                    Welcome https://t.co/iVryzHH1MA     FR       en
# 12579018                  Visiting #Stockholm this weekend.     ZH       en
# 12579027  @MarkGSparrow I'll admit that it was difficult...     ZG       en
# 12579031                      Switzerland, you are a dream      OW       en
#
#           polarity
# 0         1.000000
# 1         0.000000
# 2         0.200000
# 4         0.000000
# 6         0.000000
# 7         0.107576
# 8         0.000000
# 9        -0.300000
# 10        0.000000
# 11        0.000000
# 14        0.000000
# 15        0.000000
# 16        0.250000
# 17        0.200000
# 18        0.000000
# 19        0.000000
# 20        0.500000
# 22        0.236174
# 23        0.000000
# 28        0.000000
# 29        0.000000
# 30        0.000000
# 31        0.383333
# 32        0.000000
# 33        0.000000
# 34        0.000000
# 35        0.000000
# 37        0.300000
# 38        0.000000
# 39        0.366211
# ...            ...
# 12578885  0.000000
# 12578895  0.000000
# 12578906 -0.250000
# 12578919  0.800000
# 12578922  0.000000
# 12578924  0.200000
# 12578931  0.000000
# 12578932  0.000000
# 12578934  0.000000
# 12578935  0.000000
# 12578936 -0.333333
# 12578943  0.000000
# 12578957  0.600000
# 12578960  0.000000
# 12578963  0.500000
# 12578964  0.500000
# 12578969  0.000000
# 12578975  0.136364
# 12578976  0.000000
# 12578983  0.250000
# 12578985  0.000000
# 12578988  0.000000
# 12578993  0.000000
# 12578994  0.000000
# 12579000  0.527083
# 12579003  0.166667
# 12579008  0.800000
# 12579018  0.000000
# 12579027 -0.500000
# 12579031  0.000000
#
# [2985994 rows x 7 columns]

# %% [markdown]
# # French

# %%
tweet_fr=tweet[tweet['language']=='fr']

# %%
len(tweet_fr)
# Out:
# 3500272

# %%
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())
blob1 = tb(u"Quelle belle matinée")
blob1.sentiment
# Out:
# (0.8, 0.8)

# %%
text_list=tweet_fr.text.tolist()
claned_text=[]
for t in text_list:
    claned_text.append(clean_up_text(t))

# %%
score=[]
i=0
for text in claned_text:  
    blob2 = tb(text)
    score.append(blob2.sentiment[0])
    i+=1
    if (i%100000 == 0):
        print(i)
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000

# %%
#https://github.com/sloria/textblob-fr

# %%
tweet_fr['polarity']=score
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# # German

# %%
tweet_de=tweet[tweet['language']=='de']

# %%
len(tweet_de)
# Out:
# 1402170

# %%
text_list=tweet_de.text.tolist()
claned_text=[]
for t in text_list:
    claned_text.append(clean_up_text(t))

# %%
from textblob_de import TextBlobDE as TextBlob

# %%
score=[]
i=0
for text in text_list:  
    blob = TextBlob(text)
    score.append(blob.sentiment[0])
    i+=1
    if (i%10000 == 0):
        print(i)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# 1140000
# 1150000
# 1160000
# 1170000
# 1180000
# 1190000
# 1200000
# 1210000
# 1220000
# 1230000
# 1240000
# 1250000
# 1260000
# 1270000
# 1280000
# 1290000
# 1300000
# 1310000
# 1320000
# 1330000
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# 1390000
# 1400000

# %%
len(score)
# Out:
# 1402170

# %%
tweet_de['polarity']=score
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tweet_fr_en_de_polarity=pd.concat([tweet_en,tweet_fr,tweet_de])

# %%
tweet_fr_en_de_polarity.tail()
# Out:
#             index            id        userId            createdAt  \
# 7888431  12579023  7.768213e+17  7.409830e+05  2016-09-16 16:33:31
# 7888432  12579028  7.768216e+17  7.666746e+17  2016-09-16 16:34:31
# 7888433  12579030  7.768216e+17  3.233408e+09  2016-09-16 16:34:39
# 7888434  12579032  7.768217e+17  5.086385e+08  2016-09-16 16:34:58
# 7888435  12579033  7.768217e+17  7.666746e+17  2016-09-16 16:35:03
#
#                                                       text canton language  \
# 7888431  Laurent Haug @ Techno-Pôle de Sierre (TechnoAr...     VS       de
# 7888432  Dratini – beim Inseli bis 18:42:59 https://t.c...     LU       de
# 7888433  Jetzt habe ich sehr viel Filmmaterial von den ...     ZH       de
# 7888434  @dbrgn 50% Fremdschämeffekt bei den Firmenpitc...     UR       de
# 7888435  Ponita – beim Torbogen bis 18:46:14 https://t....     LU       de
#
#          polarity
# 7888431       0.0
# 7888432       0.0
# 7888433       0.0
# 7888434       0.0
# 7888435       0.0

# %%
tweet_fr_en_de_polarity=tweet_fr_en_de_polarity.reset_index()

# %%
len(tweet_fr_en_de_polarity)
# Out:
# 7888436

# %%
tweet_fr_en_de_polarity.to_csv('tweet_fr_en_de_polarity.csv', index=None)
